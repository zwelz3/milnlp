# %%
import re
import nltk

from sumy.nlp.tokenizers import Tokenizer

from milnlp.converters.pdf_to_text import PdfConverter, create_text, create_sumy_dom
from milnlp.converters.new_text_utils import RawTextProcessing
from milnlp.collection.utils.qol import doc_to_text

# %%
filepath = "pdf_examples/normal_document.pdf"
# filepath = "pdf_examples/powerpoint.pdf"
# filepath = "pdf_examples/glossary.pdf" 
# filepath = "pdf_examples/challenge.pdf"
# filepath = "pdf_examples/graphene.pdf"

converter = PdfConverter()
raw_document = converter.convert_pdf(filepath, to_file=False)
tokenizer = Tokenizer('English')

# %%
import re
import nltk

# Regex Patterns
page_pattern = re.compile(r"\f")
unicode_pattern = re.compile(r"[^\x00-\x7F]")
wordref_pattern = re.compile(r"([a-z]{3,})[\[]?[\d]+[,-]?[\d]*[\]]?")  # https://regexr.com/4213c

# Sets for lookup
normal_chars = set([char for char in ":,.?!-\"\'\(\)"])
normal_punct = set([char for char in ".?!\"\'\)"])
basic_pos = {'JJ','JJR','JJS','NN','NNP','NNS'}  # these POS alone are not enough for a valid "natural language" sentence

TUNABLE_MAX_NUPW = 0.05  # the maximum number of unicode symbols per words (freq) for a sentence before the sentence is excluded
TUNABLE_MIN_SPC = 2  # the minimum number of sentences per 1 chunk before the chunk is discarded.
TUNABLE_MAX_CPU = 2  # the maximum number of expected characters in any unit (cm^3 = 2) used to discard reference indices (something23)
TUNABLE_MIN_WPS = 6  # the minimum number of nltk tokenized 'words' in a sentence before the sentence is thrown out
TUNABLE_MAX_WPS = 50  # the maximum number of nltk tokenized 'words' in a sentence before the sentence is thrown out

raw_text = raw_document

pages = page_pattern.finditer(raw_text)
all_sentences = []
processed_pages = []
start = 0
# Break document into pages
for pi, page in enumerate(pages):
    end, new_start = page.span()
    page_text = raw_text[start:end]
    start = new_start

    # Break page into chunks
    processed_chunks = []
    chunks = page_text.split('\n\n')
    for ci, chunk in enumerate(chunks):
        # Remove newlines from chunk
        chunk_text = chunk.replace('\n', ' ').replace('  ',
                                                      ' ')  # todo this is merging headers into sentences. Replace with intelligent check
                                                            # ex: normal_document

        # Break chunk into sentences
        processed_sentences = []
        for sentence in nltk.sent_tokenize(chunk_text):

            # Add steps here to clean up words+ref (i.e. parnel28)
            replacement_map = [(match.group(0), match.group(1)) for match in wordref_pattern.finditer(sentence)]
            for before, after in replacement_map:
                sentence = sentence.replace(before, after)

            # Get words and POS-tagged words for next steps
            words = nltk.word_tokenize(sentence)
            num_valid_words = sum([tokenizer._is_word(word) for word in words])
            pos_words = nltk.pos_tag(
                words)  # todo '|' char is being tagged as word instead of symbol (i.e. JJ, NN)
                        # todo likely a unicode error (nltk not trained on unicode for english?)

            # Test number of unicode symbols in the sentence
            nu = len(unicode_pattern.findall(sentence))  # nu = number of unicode chars
            nupw = nu / len(words)
            # Test number of NN+JJ to make sure sentence is 'natural'
            explanatory_pos = set([pos for _, pos in pos_words]).difference(normal_chars.union(basic_pos))

            # Add to sentences if passing checks
            if nupw <= TUNABLE_MAX_NUPW and \
                TUNABLE_MAX_WPS > num_valid_words >= TUNABLE_MIN_WPS and \
                explanatory_pos:
                if sentence.strip()[-1] not in normal_punct:
                    sentence += '.'
                processed_sentences.append(sentence)
                all_sentences.append(sentence)

        # Add to chunks if passing checks
        if len(processed_sentences) >= TUNABLE_MIN_SPC:
            processed_chunks.append(processed_sentences)

    processed_pages.append(processed_chunks)
    
document_sentences = all_sentences

# %%
# Add to DOM (since that is how tool does it)
document = create_sumy_dom(document_sentences, tokenizer)

# Use doc_to_text
doc_text = doc_to_text(document)

# %% [markdown]
# ## Testing

# %%
document_sentences
# Out:
# ['MOTIVATION The goal is to provide decision makers with an agile and defensible approach to making system acquisition and system employment decisions.',
#  'Primarily to allow them to tradeoff potential EW concepts and identify S&T investment strategies.',
#  'This proposed implementation is intended to provide decision makers with an ability to interactively assess the value (from a functional and capability standpoint) of aggregations of EW systems and suites for various airframes.',
#  'The notional example presented is based on a rapid prototype developed by GTRI to illustrate how such a process could be implemented quickly as an Excel tradeoff tool to evaluate various EW suites for a USAF combat aircraft.',
#  'The process and tool could be extended to allow for the comparison of multiple types of aircraft flying independent and joint missions.',
#  'The process is intended to integrate the world-view and concerns from two groups of stakeholders, namely (1) the domain subject matter experts (SMEs), and (2) the decision makers (DMs).',
#  'The SMEs are experts in at least some portion of the operational and technological aspects of a particular concern (e.g., for electronic warfare, they may be well versed in how the USAF employs EW assets and equipment, or how the technology and/or adversary is evolving).',
#  'The DMs have to integrate the inputs from groups of SMEs to identify solutions that balance the concerns within a wide range of conditions or needs, including mission, scenarios, budget, etc.',
#  'The dialogue between the two groups is key to identifying suitable solutions in a timely manner.',
#  'There are multiple risks involved with insufficient communication between the two groups, e.g., (1) having the SMEs ignore or not be aware of concerns that are critical to the DMs, (2) DMs being unaware of tacit assumptions by the SMEs which invalidate a higher level decision.',
#  'These risks often manifest themselves during a decision exercise (where SMEs are generally not available) or during a SMEs’ briefing to the DMs.',
#  'These misunderstandings may require the SMEs to reconvene to reassess their recommendations to the DMs, bogging the process down.',
#  'Figure 1 depicts the rationale for the proposed approach, which tries to strike a balance between the defensible but resource intensive quantitative methods versus the agile but less defensible BOGSAT techniques.',
#  'Oftentimes, acquisition decisions are supported by a BOGSAT1 exercise that takes input from a variety of experts who will base their recommendations on their experience, prior analyses (e.g., Modeling & Simulation (M&S)) and other sources (e.g., intel reports).',
#  'This approach is agile in the sense that as new information (e.g., new intel, new specifications from decision makers) is provided, the team can pivot and take it into account in an ad-hoc manner.',
#  'If this approach was to be contrasted to a more quantitative approach, one could envision a yet-to-be-developed artificial intelligence (AI) system that could ingest vast amounts of information and provide answers to questions (à la IBM’s Watson).',
#  'This comparison is only useful to delineate the bounds of this potential spectrum of decision support approaches.',
#  'The concept of agility for this notional AI system is difficult to assess but, if the capabilities of that system are aligned with existing capabilities, the most quantitative approach that can be conceived is probably one that is driven by detailed M&S exercises.',
#  'These exercises are defensible in the sense that they are conducted using trusted tools, and analysts and decision makers can trace what.',
#  '                              1 BOGSAT: Bunch of Guys/Gals Sitting Around a Table.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.',
#  'causes produced the effects of interest.',
#  'That is not to say that the team of SMEs do not have a good rationale for their recommendations, but they may need to consult with their notes and other team members to recall why a particular solution was discounted, or ignored.',
#  'The proposed solution strives to achieve a balance between the BOGSAT and the M&S approaches.',
#  'SPANNING THE SPECTRUM OF DECISION SUPPORT APPROACHES.',
#  'The top-down portion of the process begins by identifying high-level missions or objectives that must be accomplished.',
#  'In the notional example presented in this paper there are six (6) high-level missions that the aircraft must participate in, as shown in Table 1.',
#  'A different implementation may identify other missions, or a different category of functional capability, e.g., performance against specific adversaries in specific scenarios.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.',
#  'SME-based Executive DashboardDecision Support FrameworkBOGSATAutomated Decision MakingModeling & SimulationIndividual AssessmentsIntelM&S.',
#  'NOTIONAL LIST OF HIGH-LEVEL FUNCTIONAL OBJECTIVES (IN THIS CASE: MISSIONS)',
#  '1 Conduct Homeland Defense 2 Achieve Air Superiority in Contested airspace 3 Support Air Supremacy in Contested airspace (SEAD) 4 Support Air parity in denied-access airspace (5th Gen Enabler) 5 Support Air Superiority in denied-access airspace (5th Gen Enabler + Missile Truck) 6 DCA in Contested airspace.',
#  'Once the missions (or some other high-level set of objectives) has been identified, the GTRI team will engage with EW SMEs from GTRI and the Government to decompose them into system or component- level functionality.',
#  'These functions will then be mapped to the alternatives being considered (e.g., a new IRCM system, improved communications system, updated radar warning receiver) to quantify the functionality provided by each one.',
#  'Selecting the appropriate high-level measure of value and decomposing it is an exercise that requires engaging with the decision makers (to identify their interests are being considered) and the SMEs (to ensure the intermediate mappings can be quantified).',
#  'GTRI will leverage doctrine to prototype and provide initial thoughts as to what the potential approaches are to measuring the highest-level of functional capability (top-down), and identify the common functions from all the elements considered (bottom-up) to minimize the time required from Government DMs and SMEs.',
#  'In the notional example, the Missions are broken into groups of functions (Table 2) that are then mapped to the individual systems.',
#  'The mapping between the functions and the missions is done by answering the question: “If Function X cannot be performed or can only be partially performed, what is the impact to the satisfaction of the mission?” Figure 2 depicts a notional set of values for this mapping.',
#  ' t e g r a T / k c a r T / x i F / d n i F.',
#  'a r e n e G.',
#  'k c a r T x i F d n i F T S R I / R O E.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.',
#  'k c a r T x i F d n i F F R.',
#  'a c i n o r t c e l E  /  e g a g n E W E.',
#  'k c a t t A.',
#  ' t r o p p u S n o i s s i.',
#  ' s n o i t c n u F.',
#  'RF Detect Gen I SAM/AAA RF Detect Gen II SAM/AAA RF Detect Gen III SAM/AAA RF Detect Gen I AI RF Detect Gen II AI RF Detect Gen III AI RF Discriminate SAM/AAA in Dense Environment RF Discriminate AI in Dense Environment.',
#  'The GTRI team would work with its EW SMEs and Government EW SMEs to iterate over possible approaches and identify the most effective one, namely the one that captures the prerequisite phenomena and requires data that can be elicited in the allotted time with the assigned resources.',
#  'These mappings provide a quantitative and traceable means to mathematically assess the ability of each combination of EW systems to satisfy the intermediate and high-level functional needs.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.',
#  'A notional dashboard is presented in Figure 3, with a list of systems on the left-most panel that can be selected using checkboxes.',
#  'As the DMs select systems, the capability value of the integrated system increases.',
#  'This is represented in the ability to satisfy the needs of the six high-level missions (top bar chart), and the functions for a specific functional area (bottom right).',
#  'The decision makers can also filter solutions by their total cost, fielding year, technology readiness level, etc.',
#  'The gray bubbles represent solutions that were generated during prior uses, or using an optimization algorithm (e.g., a genetic algorithm).',
#  'In this case, the filled gray circles are combinations that are still viable, while the dashed lined circles are combinations that do not meet one or more constraints (e.g., fielding year, TRL, budget, EW FoM).',
#  'The approach can be augmented to formulate and evaluate S&T plans to mature the most promising technologies.',
#  'The S&T module would require identifying technology maturation plans for each system with a low TRL or IRL, and including those costs in the overall system cost.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.',
#  'risk of each technology, and identify the risk of the overall portfolio by assessing that in conjunction with the functional overlap (e.g., a form of technology/functional redundancy) of the evaluated solutions.',
#  'It is important to emphasize that this is a notional dashboard to illustrate the realm of the possible, and any dashboard developed for the EW ECCT Assessment would have to be iterated with the decision makers to ensure it accommodates their priorities and concerns.',
#  'CONCLUSION This whitepaper provides an approach to assess the functional value of combinations of EW systems.',
#  'The product of this exercise is an executive decision support dashboard that can be used by teams of decision makers to play what-if games in terms of their priorities for satisfying various levels of functional needs, as they enable and disable alternatives.',
#  'The approach can be expanded to assess S&T plans to help mature the technologies and assess the portfolios in terms of their overall technology development risk and cost.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.',
#  'The total ROM cost for the effort, including additional program management, as well as EW SME support from GTRI is $240,000 in labor and $10,000 in travel for a total of $250,000.',
#  'Level of Effort 20% FTE 100% FTE 35% FTE.',
#  'THE GEORGIA INSTITUTE OF TECHNOLOGY OFFICE OF SPONSORED PROGRAMS (404-894-6919) IS THE ONLY OFFICE AUTHORIZED TO SUBMIT OFFICIAL PROPOSALS AND NEGOTIATE R&D GRANTS AND CONTRACTS.']
